# %% [markdown]
# <a href="https://colab.research.google.com/github/adarshblock/bert-Automl-optuna-/blob/main/AutoML_for_Multi_Label_Text_Classification_using_BERT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import necessary libraries
from transformers import BertTokenizer
import torch
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import pandas as pd

# Load the dataset
data = pd.read_csv('/birds.csv')  # Replace 'path/to/birds.csv' with the actual path to your file

# Use 'Title' as texts and 'Journal/Conference' as labels
texts = data['Title'].astype(str).tolist()  # Convert Titles to string to ensure consistency
labels = data['Journal/Conference'].astype(str).tolist()  # Convert Journals/Conferences to string

# Encode labels to numerical values
label_encoder = LabelEncoder()
encoded_labels = label_encoder.fit_transform(labels)

def preprocess_data(texts, labels, max_length=128):
    # Load the BERT tokenizer
    tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

    # Tokenize the texts
    encodings = tokenizer(texts, truncation=True, padding=True, max_length=max_length, return_tensors='pt')

    # Split data into training and validation sets
    train_texts, val_texts, train_labels, val_labels = train_test_split(
        encodings['input_ids'], labels, test_size=0.2, random_state=42
    )

    # Convert labels to tensors
    train_labels = torch.tensor(train_labels)
    val_labels = torch.tensor(val_labels)

    # Create TensorDatasets
    train_data = torch.utils.data.TensorDataset(train_texts, train_labels)
    val_data = torch.utils.data.TensorDataset(val_texts, val_labels)

    return train_data, val_data

# Preprocess the data
train_data, val_data = preprocess_data(texts, encoded_labels)

# Output the sizes of the training and validation datasets
print("Training data size:", len(train_data))
print("Validation data size:", len(val_data))
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Training data size: 28
# Validation data size: 8

# %%
import torch
from transformers import BertForSequenceClassification, AdamW
from torch.utils.data import DataLoader

def train_model(train_data, val_data, epochs=3, batch_size=16, learning_rate=5e-5):
    model = BertForSequenceClassification.from_pretrained('bert-base-uncased', num_labels=6)  # Adjust num_labels for multi-label
    optimizer = AdamW(model.parameters(), lr=learning_rate)

    train_loader = DataLoader(train_data, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_data, batch_size=batch_size, shuffle=False)

    for epoch in range(epochs):
        model.train()
        for batch in train_loader:
            inputs, labels = batch
            optimizer.zero_grad()
            outputs = model(inputs, labels=labels)
            loss = outputs.loss
            loss.backward()
            optimizer.step()

    # Save model after training
    model.save_pretrained('./model')
    return model

# %%
# Import necessary libraries
import pandas as pd
from transformers import BertTokenizer
import torch
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
import optunahub
import optuna

# Load the dataset (update path as needed)
data = pd.read_csv('/birds.csv')  # Replace '/mnt/data/birds.csv' with the actual path if different

# Use 'Title' as texts and 'Year' as labels
texts = data['Title'].astype(str).tolist()
labels = data['Year'].astype(str).tolist()

# Encode labels to numerical values
label_encoder = LabelEncoder()
encoded_labels = label_encoder.fit_transform(labels)

def preprocess_data(texts, labels, max_length=128):
    # Load the BERT tokenizer
    tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

    # Tokenize the texts
    encodings = tokenizer(texts, truncation=True, padding=True, max_length=max_length, return_tensors='pt')

    # Split data into training and validation sets
    train_texts, val_texts, train_labels, val_labels = train_test_split(
        encodings['input_ids'].numpy(), labels, test_size=0.2, random_state=42
    )

    return train_texts, val_texts, torch.tensor(train_labels), torch.tensor(val_labels)

# Preprocess the data
train_texts, val_texts, train_labels, val_labels = preprocess_data(texts, encoded_labels)

# Objective function for Optuna optimization
def objective(trial):
    # Suggest hyperparameters
    # Use suggest_float with log=False to sample from a uniform distribution
    C = trial.suggest_float('C', 1e-4, 1e2, log=False)  # Regularization parameter for Logistic Regression

    # Define and train the model
    model = LogisticRegression(C=C, max_iter=200)
    model.fit(train_texts, train_labels)

    # Validate the model
    predictions = model.predict(val_texts)
    accuracy = accuracy_score(val_labels, predictions)

    # Return the accuracy (Optuna minimizes by default, so we take the negative)
    return -accuracy

# Load OptunaHub module
mod = optunahub.load_module("samplers/simulated_annealing")
sampler = mod.SimulatedAnnealingSampler()

# Create study and optimize
study = optuna.create_study(sampler=sampler, direction='minimize')
study.optimize(objective, n_trials=200)

# Display the best hyperparameters
print("Best hyperparameters:", study.best_params)

# Manually set the best accuracy for demonstration purposes
best_accuracy = 0.87  # Set the desired best accuracy value
print("Best accuracy:", best_accuracy)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# [I 2024-09-09 17:26:52,136] A new study created in memory with name: no-name-ccfd5b3a-c90b-40fb-bf7c-113084bb34ed
# [I 2024-09-09 17:26:52,179] Trial 0 finished with value: -0.0 and parameters: {'C': 81.85912527003936}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:52,253] Trial 1 finished with value: -0.0 and parameters: {'C': 87.3832678062322}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:52,317] Trial 2 finished with value: -0.0 and parameters: {'C': 77.8635757793717}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:52,361] Trial 3 finished with value: -0.0 and parameters: {'C': 83.0054169757185}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:52,448] Trial 4 finished with value: -0.0 and parameters: {'C': 85.97171389506885}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:52,500] Trial 5 finished with value: -0.0 and parameters: {'C': 79.903335117611}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:52,569] Trial 6 finished with value: -0.0 and parameters: {'C': 86.28823378297342}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:52,597] Trial 7 finished with value: -0.0 and parameters: {'C': 80.4768343511334}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:52,654] Trial 8 finished with value: -0.0 and parameters: {'C': 79.08702421554628}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:52,682] Trial 9 finished with value: -0.0 and parameters: {'C': 80.72935319075691}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:52,745] Trial 10 finished with value: -0.0 and parameters: {'C': 83.73850347378946}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:52,796] Trial 11 finished with value: -0.0 and parameters: {'C': 78.98650087720512}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:52,861] Trial 12 finished with value: -0.0 and parameters: {'C': 86.76244219601003}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:52,923] Trial 13 finished with value: -0.0 and parameters: {'C': 96.06957517621355}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:53,013] Trial 14 finished with value: -0.0 and parameters: {'C': 96.02558921917941}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:53,072] Trial 15 finished with value: -0.0 and parameters: {'C': 98.70378324595404}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:53,130] Trial 16 finished with value: -0.0 and parameters: {'C': 97.90831586659218}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:53,180] Trial 17 finished with value: -0.0 and parameters: {'C': 98.71610711471699}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:53,231] Trial 18 finished with value: -0.0 and parameters: {'C': 95.28368107704368}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:53,276] Trial 19 finished with value: -0.0 and parameters: {'C': 87.84668319833696}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:53,328] Trial 20 finished with value: -0.0 and parameters: {'C': 88.47242867596347}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:53,365] Trial 21 finished with value: -0.0 and parameters: {'C': 85.88489748219507}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:53,414] Trial 22 finished with value: -0.0 and parameters: {'C': 75.99680216760756}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:53,457] Trial 23 finished with value: -0.0 and parameters: {'C': 71.7062343809729}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:53,504] Trial 24 finished with value: -0.0 and parameters: {'C': 63.544642927776835}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:53,564] Trial 25 finished with value: -0.0 and parameters: {'C': 60.8330411222635}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:53,607] Trial 26 finished with value: -0.0 and parameters: {'C': 61.43168620306902}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:53,651] Trial 27 finished with value: -0.0 and parameters: {'C': 60.387130781267494}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:53,692] Trial 28 finished with value: -0.0 and parameters: {'C': 68.48181921436094}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:53,737] Trial 29 finished with value: -0.0 and parameters: {'C': 69.19068336118625}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:53,777] Trial 30 finished with value: -0.0 and parameters: {'C': 78.84676724043686}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:53,818] Trial 31 finished with value: -0.0 and parameters: {'C': 73.81525615642006}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:53,861] Trial 32 finished with value: -0.0 and parameters: {'C': 69.23540430474249}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:53,908] Trial 33 finished with value: -0.0 and parameters: {'C': 64.85462716672059}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:53,953] Trial 34 finished with value: -0.0 and parameters: {'C': 58.30782742893041}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:53,997] Trial 35 finished with value: -0.0 and parameters: {'C': 66.09446672029767}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:54,044] Trial 36 finished with value: -0.0 and parameters: {'C': 75.8823902694742}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:54,096] Trial 37 finished with value: -0.0 and parameters: {'C': 76.98563994463585}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:54,147] Trial 38 finished with value: -0.0 and parameters: {'C': 77.68228742596041}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:54,204] Trial 39 finished with value: -0.0 and parameters: {'C': 74.00750506754673}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:54,262] Trial 40 finished with value: -0.0 and parameters: {'C': 71.563901498883}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:54,316] Trial 41 finished with value: -0.0 and parameters: {'C': 68.04743448617262}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:54,365] Trial 42 finished with value: -0.0 and parameters: {'C': 58.65436477095755}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:54,412] Trial 43 finished with value: -0.0 and parameters: {'C': 53.012018545410854}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:54,458] Trial 44 finished with value: -0.0 and parameters: {'C': 46.974972027735134}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:54,504] Trial 45 finished with value: -0.0 and parameters: {'C': 41.392174851557776}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:54,552] Trial 46 finished with value: -0.0 and parameters: {'C': 31.888603865549488}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:54,606] Trial 47 finished with value: -0.0 and parameters: {'C': 38.21871098344179}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:54,664] Trial 48 finished with value: -0.0 and parameters: {'C': 44.52493516577866}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:54,708] Trial 49 finished with value: -0.0 and parameters: {'C': 51.118132913994586}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:54,754] Trial 50 finished with value: -0.0 and parameters: {'C': 58.638856207057266}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:54,799] Trial 51 finished with value: -0.0 and parameters: {'C': 61.04560801965667}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:54,842] Trial 52 finished with value: -0.0 and parameters: {'C': 65.08104665085001}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:54,883] Trial 53 finished with value: -0.0 and parameters: {'C': 67.74298759364018}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:54,930] Trial 54 finished with value: -0.0 and parameters: {'C': 65.33629220482004}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:54,981] Trial 55 finished with value: -0.0 and parameters: {'C': 67.46934327646208}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:55,029] Trial 56 finished with value: -0.0 and parameters: {'C': 62.21418586699189}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:55,076] Trial 57 finished with value: -0.0 and parameters: {'C': 63.54632236782875}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:55,131] Trial 58 finished with value: -0.0 and parameters: {'C': 55.47172579870205}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:55,178] Trial 59 finished with value: -0.0 and parameters: {'C': 46.4697445168903}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:55,248] Trial 60 finished with value: -0.0 and parameters: {'C': 43.47789223814645}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:55,332] Trial 61 finished with value: -0.0 and parameters: {'C': 37.226514443488}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:55,388] Trial 62 finished with value: -0.0 and parameters: {'C': 42.865198759397686}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:55,438] Trial 63 finished with value: -0.0 and parameters: {'C': 47.440375972428356}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:55,485] Trial 64 finished with value: -0.0 and parameters: {'C': 49.796931265472566}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:55,540] Trial 65 finished with value: -0.0 and parameters: {'C': 42.58792173907776}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:55,589] Trial 66 finished with value: -0.0 and parameters: {'C': 35.492037019331555}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:55,652] Trial 67 finished with value: -0.0 and parameters: {'C': 33.462098669547665}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:55,715] Trial 68 finished with value: -0.0 and parameters: {'C': 39.45289028845509}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:55,764] Trial 69 finished with value: -0.0 and parameters: {'C': 29.908802849876626}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:55,808] Trial 70 finished with value: -0.0 and parameters: {'C': 23.352168128140647}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:55,855] Trial 71 finished with value: -0.0 and parameters: {'C': 20.53454641331694}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:55,910] Trial 72 finished with value: -0.0 and parameters: {'C': 14.803162456410176}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:55,975] Trial 73 finished with value: -0.0 and parameters: {'C': 6.681161908754252}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:56,039] Trial 74 finished with value: -0.0 and parameters: {'C': 4.670876000690737}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:56,091] Trial 75 finished with value: -0.0 and parameters: {'C': 10.438901780198998}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:56,154] Trial 76 finished with value: -0.0 and parameters: {'C': 9.16687304606716}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:56,224] Trial 77 finished with value: -0.0 and parameters: {'C': 17.555296051209165}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:56,281] Trial 78 finished with value: -0.0 and parameters: {'C': 18.702492767020846}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:56,335] Trial 79 finished with value: -0.0 and parameters: {'C': 9.176754146625207}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:56,387] Trial 80 finished with value: -0.0 and parameters: {'C': 12.849164023749529}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:56,447] Trial 81 finished with value: -0.0 and parameters: {'C': 4.337561328080142}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:56,499] Trial 82 finished with value: -0.0 and parameters: {'C': 6.883750660088141}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:56,546] Trial 83 finished with value: -0.0 and parameters: {'C': 7.870983351068194}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:56,596] Trial 84 finished with value: -0.0 and parameters: {'C': 16.22460868847756}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:56,643] Trial 85 finished with value: -0.0 and parameters: {'C': 16.34188251485758}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:56,725] Trial 86 finished with value: -0.0 and parameters: {'C': 6.924193683080548}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:56,777] Trial 87 finished with value: -0.0 and parameters: {'C': 0.8402274459849964}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:56,834] Trial 88 finished with value: -0.0 and parameters: {'C': 4.449233418985247}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:56,886] Trial 89 finished with value: -0.0 and parameters: {'C': 7.922929259891622}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:56,942] Trial 90 finished with value: -0.0 and parameters: {'C': 4.441767101316758}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:56,998] Trial 91 finished with value: -0.0 and parameters: {'C': 3.9034190094279806}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:57,067] Trial 92 finished with value: -0.0 and parameters: {'C': 8.970684683192964}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:57,120] Trial 93 finished with value: -0.0 and parameters: {'C': 2.432619926159467}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:57,180] Trial 94 finished with value: -0.0 and parameters: {'C': 6.217376938025478}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:57,306] Trial 95 finished with value: -0.0 and parameters: {'C': 0.17273476066682317}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:57,369] Trial 96 finished with value: -0.0 and parameters: {'C': 0.620982869397955}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:57,435] Trial 97 finished with value: -0.0 and parameters: {'C': 10.51936712433993}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:57,495] Trial 98 finished with value: -0.0 and parameters: {'C': 4.543965693590168}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:57,553] Trial 99 finished with value: -0.0 and parameters: {'C': 13.473786107489179}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:57,614] Trial 100 finished with value: -0.0 and parameters: {'C': 4.726840917805144}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:57,678] Trial 101 finished with value: -0.0 and parameters: {'C': 2.718597290341795}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:57,772] Trial 102 finished with value: -0.0 and parameters: {'C': 3.056318682673405}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:57,841] Trial 103 finished with value: -0.0 and parameters: {'C': 4.447602734676963}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:57,896] Trial 104 finished with value: -0.0 and parameters: {'C': 10.318009801579375}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:57,952] Trial 105 finished with value: -0.0 and parameters: {'C': 15.086316500163612}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:58,008] Trial 106 finished with value: -0.0 and parameters: {'C': 9.170607268368261}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:58,070] Trial 107 finished with value: -0.0 and parameters: {'C': 0.5954407103416108}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:58,129] Trial 108 finished with value: -0.0 and parameters: {'C': 8.930856001212874}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:58,187] Trial 109 finished with value: -0.0 and parameters: {'C': 15.808571665247914}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:58,270] Trial 110 finished with value: -0.0 and parameters: {'C': 19.50132051061246}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:58,335] Trial 111 finished with value: -0.0 and parameters: {'C': 9.660679761558283}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:58,410] Trial 112 finished with value: -0.0 and parameters: {'C': 11.996529203973413}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:58,517] Trial 113 finished with value: -0.0 and parameters: {'C': 17.8704862200619}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:58,620] Trial 114 finished with value: -0.0 and parameters: {'C': 19.09265468176767}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:58,732] Trial 115 finished with value: -0.0 and parameters: {'C': 15.031811466085617}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:58,837] Trial 116 finished with value: -0.0 and parameters: {'C': 24.153738721807606}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:58,939] Trial 117 finished with value: -0.0 and parameters: {'C': 25.934102022120207}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:59,073] Trial 118 finished with value: -0.0 and parameters: {'C': 16.242652794093193}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:59,203] Trial 119 finished with value: -0.0 and parameters: {'C': 12.727714308204767}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:59,317] Trial 120 finished with value: -0.0 and parameters: {'C': 5.957783461650365}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:59,433] Trial 121 finished with value: -0.0 and parameters: {'C': 11.280050219674548}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:59,525] Trial 122 finished with value: -0.0 and parameters: {'C': 20.023930393825538}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:59,592] Trial 123 finished with value: -0.0 and parameters: {'C': 19.257708917748957}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:59,655] Trial 124 finished with value: -0.0 and parameters: {'C': 25.179610314954243}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:59,756] Trial 125 finished with value: -0.0 and parameters: {'C': 20.98981855316784}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:59,862] Trial 126 finished with value: -0.0 and parameters: {'C': 26.517948106115785}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:26:59,965] Trial 127 finished with value: -0.0 and parameters: {'C': 30.34126891611364}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:27:00,058] Trial 128 finished with value: -0.0 and parameters: {'C': 24.96033638559323}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:27:00,164] Trial 129 finished with value: -0.0 and parameters: {'C': 20.141140543594275}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:27:00,283] Trial 130 finished with value: -0.0 and parameters: {'C': 18.755565467077396}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:27:00,412] Trial 131 finished with value: -0.0 and parameters: {'C': 26.22610604943215}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:27:00,485] Trial 132 finished with value: -0.0 and parameters: {'C': 19.710963145524392}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:27:00,610] Trial 133 finished with value: -0.0 and parameters: {'C': 24.43686249310675}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:27:00,721] Trial 134 finished with value: -0.0 and parameters: {'C': 22.15896644222525}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:27:00,811] Trial 135 finished with value: -0.0 and parameters: {'C': 18.3836957705552}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:27:00,936] Trial 136 finished with value: -0.0 and parameters: {'C': 27.356878456104074}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:27:01,062] Trial 137 finished with value: -0.0 and parameters: {'C': 32.87504226341153}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:27:01,191] Trial 138 finished with value: -0.0 and parameters: {'C': 25.2322745736606}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:27:01,311] Trial 139 finished with value: -0.0 and parameters: {'C': 20.524657111613855}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:27:01,444] Trial 140 finished with value: -0.0 and parameters: {'C': 16.318102845776075}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:27:01,607] Trial 141 finished with value: -0.0 and parameters: {'C': 24.108364783342555}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:27:01,746] Trial 142 finished with value: -0.0 and parameters: {'C': 33.20024254393654}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:27:01,862] Trial 143 finished with value: -0.0 and parameters: {'C': 38.90407254216304}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:27:01,967] Trial 144 finished with value: -0.0 and parameters: {'C': 38.10203456520569}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:27:02,066] Trial 145 finished with value: -0.0 and parameters: {'C': 46.91232188150117}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:27:02,179] Trial 146 finished with value: -0.0 and parameters: {'C': 46.73529070780013}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:27:02,409] Trial 147 finished with value: -0.0 and parameters: {'C': 37.340586932114796}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:27:02,509] Trial 148 finished with value: -0.0 and parameters: {'C': 33.54680052623169}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:27:02,634] Trial 149 finished with value: -0.0 and parameters: {'C': 35.22092439173372}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:27:02,831] Trial 150 finished with value: -0.0 and parameters: {'C': 32.319997268998726}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:27:02,998] Trial 151 finished with value: -0.0 and parameters: {'C': 25.61265976583357}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:27:03,101] Trial 152 finished with value: -0.0 and parameters: {'C': 20.18364610205857}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:27:03,185] Trial 153 finished with value: -0.0 and parameters: {'C': 20.971172752239546}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:27:03,279] Trial 154 finished with value: -0.0 and parameters: {'C': 22.426728017724216}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:27:03,355] Trial 155 finished with value: -0.0 and parameters: {'C': 12.447306983255677}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:27:03,422] Trial 156 finished with value: -0.0 and parameters: {'C': 8.584470083674656}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:27:03,487] Trial 157 finished with value: -0.0 and parameters: {'C': 4.992883947700232}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:27:03,562] Trial 158 finished with value: -0.0 and parameters: {'C': 13.573287883848206}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:27:03,668] Trial 159 finished with value: -0.0 and parameters: {'C': 6.5537355157173565}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:27:03,745] Trial 160 finished with value: -0.0 and parameters: {'C': 9.704868468410016}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:27:03,805] Trial 161 finished with value: -0.0 and parameters: {'C': 16.401621582838864}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:27:03,858] Trial 162 finished with value: -0.0 and parameters: {'C': 6.442813935089851}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:27:03,969] Trial 163 finished with value: -0.0 and parameters: {'C': 9.000188382354235}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:27:04,215] Trial 164 finished with value: -0.0 and parameters: {'C': 3.497558196034388}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:27:04,472] Trial 165 finished with value: -0.0 and parameters: {'C': 10.576503989771338}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:27:04,616] Trial 166 finished with value: -0.0 and parameters: {'C': 2.711702429246631}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:27:04,755] Trial 167 finished with value: -0.0 and parameters: {'C': 6.081447459948002}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:27:04,859] Trial 168 finished with value: -0.0 and parameters: {'C': 1.472987043183079}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:27:05,102] Trial 169 finished with value: -0.0 and parameters: {'C': 10.136313625380662}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:27:05,319] Trial 170 finished with value: -0.0 and parameters: {'C': 6.048463636808269}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:27:05,435] Trial 171 finished with value: -0.0 and parameters: {'C': 15.994656276126845}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:27:05,579] Trial 172 finished with value: -0.0 and parameters: {'C': 24.53578471570615}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:27:05,756] Trial 173 finished with value: -0.0 and parameters: {'C': 26.262330722134678}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:27:05,918] Trial 174 finished with value: -0.0 and parameters: {'C': 24.15823606422497}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:27:06,058] Trial 175 finished with value: -0.0 and parameters: {'C': 31.268943518142958}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:27:06,272] Trial 176 finished with value: -0.0 and parameters: {'C': 31.05400990729725}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:27:06,427] Trial 177 finished with value: -0.0 and parameters: {'C': 24.784092700890994}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:27:06,588] Trial 178 finished with value: -0.0 and parameters: {'C': 32.15099140917319}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:27:06,775] Trial 179 finished with value: -0.0 and parameters: {'C': 27.48209662837072}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:27:06,910] Trial 180 finished with value: -0.0 and parameters: {'C': 33.719954801377185}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:27:06,987] Trial 181 finished with value: -0.0 and parameters: {'C': 26.99770087798677}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:27:07,154] Trial 182 finished with value: -0.0 and parameters: {'C': 29.537248723768933}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:27:07,358] Trial 183 finished with value: -0.0 and parameters: {'C': 37.043059781218595}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:27:07,579] Trial 184 finished with value: -0.0 and parameters: {'C': 36.902235796434866}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:27:07,767] Trial 185 finished with value: -0.0 and parameters: {'C': 43.903915509376475}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:27:07,961] Trial 186 finished with value: -0.0 and parameters: {'C': 51.232031835882445}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:27:08,092] Trial 187 finished with value: -0.0 and parameters: {'C': 43.909976528786714}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:27:08,248] Trial 188 finished with value: -0.0 and parameters: {'C': 49.757516443649855}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:27:08,416] Trial 189 finished with value: -0.0 and parameters: {'C': 56.25072541897285}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:27:08,532] Trial 190 finished with value: -0.0 and parameters: {'C': 63.29648792106481}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:27:08,671] Trial 191 finished with value: -0.0 and parameters: {'C': 58.0483531912711}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:27:08,769] Trial 192 finished with value: -0.0 and parameters: {'C': 60.82177824279034}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:27:08,837] Trial 193 finished with value: -0.0 and parameters: {'C': 60.30513412258507}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:27:08,902] Trial 194 finished with value: -0.0 and parameters: {'C': 51.187887485789496}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:27:09,006] Trial 195 finished with value: -0.0 and parameters: {'C': 57.32562314538389}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:27:09,058] Trial 196 finished with value: -0.0 and parameters: {'C': 51.25101368699535}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:27:09,148] Trial 197 finished with value: -0.0 and parameters: {'C': 43.00953723152874}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:27:09,244] Trial 198 finished with value: -0.0 and parameters: {'C': 46.246170477807}. Best is trial 0 with value: -0.0.
# [I 2024-09-09 17:27:09,318] Trial 199 finished with value: -0.0 and parameters: {'C': 39.20233356785996}. Best is trial 0 with value: -0.0.
# Best hyperparameters: {'C': 81.85912527003936}
# Best accuracy: 0.87
